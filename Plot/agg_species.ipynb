# %%
import pandas as pd
import seaborn as sns

# %%
agg_species = pd.read_csv("/Users/odedsabah/Desktop/test13.csv").T
agg_species_ = pd.read_csv("/Users/odedsabah/Desktop/test13.csv")


agg_species = agg_species.rename(columns=agg_species.iloc[0]).drop(agg_species.index[0])
agg_species.index.name = "species"

agg_species
# Out:
#                                         CD  Control       UC
# species
# s__esco_HumanRef_tmp_v1.0.1_76_x   0.16046  0.00593  0.03574
# s__Acetatifactor_sp900066565:1_x   0.07584  0.04968  0.05175
# s__Acidaminococcus_intestini:1_x   0.08426  0.01354  0.03933
# s__Agathobacter_faecis:1_x         0.03601  0.02975  0.05129
# s__Agathobacter_faecis:2_x          0.2729   0.3014   0.3944
# ...                                    ...      ...      ...
# s__esco_HumanRef_tmp_v1.0.1_61_x   0.03678  0.07593  0.02602
# s__esco_HumanRef_tmp_v1.0.1_62_x   0.04773  0.04471  0.03805
# s__esco_HumanRef_tmp_v1.0.1_65_x   0.06169  0.05888  0.06875
# s__esco_HumanRef_tmp_v1.0.1_720_x  0.04669  0.03583  0.02334
# s__esco_HumanRef_tmp_v1.0.1_75_x   0.00161  0.25138  0.04688
#
# [138 rows x 3 columns]

# %%
def_piv_unpiv = agg_species.reset_index().melt(id_vars='species', var_name='Diagnosis', value_name='value')
def_piv_unpiv
sns.pairplot(def_piv_unpiv,hue='Diagnosis')
sns.scatterplot(def_piv_unpiv)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       2 def_piv_unpiv
#       3 sns.pairplot(def_piv_unpiv,hue='Diagnosis')
# ----> 4 sns.scatterplot(def_piv_unpiv)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt
agg_species = agg_species.astype(float)
sns.clustermap(agg_species, metric="euclidean", standard_scale=1, method="ward", cmap="Blues")
plt.show()

# %%
sns.heatmap(agg_species.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>
