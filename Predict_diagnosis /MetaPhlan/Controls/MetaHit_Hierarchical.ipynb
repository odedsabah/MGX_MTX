# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
MetaHit_Hierarchical = pd.read_csv('~/Desktop/control_group/MetaHit/MetaHit_Hierarchical.csv')
MetaHit_Hierarchical = MetaHit_Hierarchical.loc[4:,:].set_index('Unnamed: 0')
MetaHit_metaphlan4 = pd.read_csv('~/Desktop/control_group/MetaHit/MetaHit.csv').set_index("Abundance").T
MetaHit_metaphlan4 = MetaHit_metaphlan4.loc[:,MetaHit_metaphlan4.columns.str.startswith('s__')].T
MetaHit_METADATA = pd.read_csv('~/Desktop/control_group/MetaHit/Study.design.txt', delimiter = "\t").set_index("Sample")
MetaHit_METADATA = MetaHit_METADATA[MetaHit_METADATA['IBD'] == 'N']
MetaHit_metaphlan4 = MetaHit_metaphlan4.loc[:,MetaHit_METADATA.index]
MetaHit_Hierarchical = MetaHit_metaphlan4.join(MetaHit_Hierarchical)
MetaHit_Hierarchical
# Out:
#                                  SAMEA728920  SAMEA728635  SAMEA728854  \
# Abundance
# s__Phocaeicola_plebeius              0.00000      0.00000      0.00000
# s__Ruminococcus_bicirculans          0.19426      0.00000      0.00000
# s__Eubacterium_rectale               0.41184     14.78986      0.10193
# s__Bacteroides_uniformis             0.05556      8.62134      6.09287
# s__Roseburia_faecis                  5.30547      2.80559      0.30419
# ...                                      ...          ...          ...
# s__Kosakonia_cowanii                     NaN          NaN          NaN
# s__Klebsiella_oxytoca                    NaN          NaN          NaN
# s__GGB14014_SGB21441                     NaN          NaN          NaN
# s__Enterobacter_huaxiensis               NaN          NaN          NaN
# s__Sutterella_megalosphaeroides          NaN          NaN          NaN
#
#                                  SAMEA728867  SAMEA728745  SAMEA728680  \
# Abundance
# s__Phocaeicola_plebeius              0.00000      0.00000      0.00000
# s__Ruminococcus_bicirculans          0.00000      0.02612      0.17761
# s__Eubacterium_rectale               2.82495      1.59172      0.00709
# s__Bacteroides_uniformis             1.08415      0.10124      0.11435
# s__Roseburia_faecis                  1.82886      1.96231      0.07721
# ...                                      ...          ...          ...
# s__Kosakonia_cowanii                     NaN          NaN          NaN
# s__Klebsiella_oxytoca                    NaN          NaN          NaN
# s__GGB14014_SGB21441                     NaN          NaN          NaN
# s__Enterobacter_huaxiensis               NaN          NaN          NaN
# s__Sutterella_megalosphaeroides          NaN          NaN          NaN
#
#                                  SAMEA728938  SAMEA728663  SAMEA728690  \
# Abundance
# s__Phocaeicola_plebeius              0.00000      0.00000      0.00000
# s__Ruminococcus_bicirculans          0.12917      0.31687      0.13045
# s__Eubacterium_rectale               2.27436      6.55611      0.20342
# s__Bacteroides_uniformis             2.84995      2.98356      0.16729
# s__Roseburia_faecis                  4.11934      9.82912      0.10694
# ...                                      ...          ...          ...
# s__Kosakonia_cowanii                     NaN          NaN          NaN
# s__Klebsiella_oxytoca                    NaN          NaN          NaN
# s__GGB14014_SGB21441                     NaN          NaN          NaN
# s__Enterobacter_huaxiensis               NaN          NaN          NaN
# s__Sutterella_megalosphaeroides          NaN          NaN          NaN
#
#                                  SAMEA728638  ...  SAMEA728780  SAMEA728794  \
# Abundance                                     ...
# s__Phocaeicola_plebeius              0.00000  ...      0.00000      0.00000
# s__Ruminococcus_bicirculans          0.00000  ...      1.82141      0.05403
# s__Eubacterium_rectale               8.34721  ...      0.73228      0.45624
# s__Bacteroides_uniformis            11.36583  ...      3.86232      1.61244
# s__Roseburia_faecis                  0.00000  ...      0.77084      0.03673
# ...                                      ...  ...          ...          ...
# s__Kosakonia_cowanii                     NaN  ...          NaN          NaN
# s__Klebsiella_oxytoca                    NaN  ...          NaN          NaN
# s__GGB14014_SGB21441                     NaN  ...          NaN          NaN
# s__Enterobacter_huaxiensis               NaN  ...          NaN          NaN
# s__Sutterella_megalosphaeroides          NaN  ...          NaN          NaN
#
#                                  SAMEA728578  SAMEA728856  SAMEA728661  \
# Abundance
# s__Phocaeicola_plebeius              0.00000      7.84554      5.43761
# s__Ruminococcus_bicirculans          1.12798      0.00000      0.46378
# s__Eubacterium_rectale               1.44026      5.43321      0.39648
# s__Bacteroides_uniformis             3.93703      7.22744      3.18182
# s__Roseburia_faecis                  0.01212      0.00000      0.35019
# ...                                      ...          ...          ...
# s__Kosakonia_cowanii                     NaN          NaN          NaN
# s__Klebsiella_oxytoca                    NaN          NaN          NaN
# s__GGB14014_SGB21441                     NaN          NaN          NaN
# s__Enterobacter_huaxiensis               NaN          NaN          NaN
# s__Sutterella_megalosphaeroides          NaN          NaN          NaN
#
#                                  SAMEA728723  SAMEA728894  SAMEA728772  \
# Abundance
# s__Phocaeicola_plebeius              0.00000      1.80892      2.89213
# s__Ruminococcus_bicirculans          2.11129      0.00000      0.48896
# s__Eubacterium_rectale               0.58292      3.05827      1.27280
# s__Bacteroides_uniformis             3.26883      0.63434      4.53111
# s__Roseburia_faecis                  0.45761      0.00000      1.93076
# ...                                      ...          ...          ...
# s__Kosakonia_cowanii                     NaN          NaN          NaN
# s__Klebsiella_oxytoca                    NaN          NaN          NaN
# s__GGB14014_SGB21441                     NaN          NaN          NaN
# s__Enterobacter_huaxiensis               NaN          NaN          NaN
# s__Sutterella_megalosphaeroides          NaN          NaN          NaN
#
#                                  SAMEA728899  \
# Abundance
# s__Phocaeicola_plebeius              0.00000
# s__Ruminococcus_bicirculans          0.08498
# s__Eubacterium_rectale               0.08124
# s__Bacteroides_uniformis             0.85308
# s__Roseburia_faecis                  0.08442
# ...                                      ...
# s__Kosakonia_cowanii                     NaN
# s__Klebsiella_oxytoca                    NaN
# s__GGB14014_SGB21441                     NaN
# s__Enterobacter_huaxiensis               NaN
# s__Sutterella_megalosphaeroides          NaN
#
#                                                                                  0
# Abundance
# s__Phocaeicola_plebeius          k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Ruminococcus_bicirculans      k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...
# s__Eubacterium_rectale           k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...
# s__Bacteroides_uniformis         k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Roseburia_faecis              k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...
# ...                                                                            ...
# s__Kosakonia_cowanii             k__Bacteria|p__Proteobacteria|c__Gammaproteoba...
# s__Klebsiella_oxytoca            k__Bacteria|p__Proteobacteria|c__Gammaproteoba...
# s__GGB14014_SGB21441             k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Enterobacter_huaxiensis       k__Bacteria|p__Proteobacteria|c__Gammaproteoba...
# s__Sutterella_megalosphaeroides  k__Bacteria|p__Proteobacteria|c__Betaproteobac...
#
# [1426 rows x 100 columns]

# %%
IBDMDB_Hierarchical = pd.read_csv('~/Desktop/Metaphlan4_set_species_control.csv')
IBDMDB_Hierarchical = IBDMDB_Hierarchical.loc[4:,:].set_index('Unnamed: 0')
IBDMDB_metaphlan4 = pd.read_csv('~/Desktop/Metaphlan4_MGX_Control.csv').set_index('Abundance').T
IBDMDB_metaphlan4 = IBDMDB_metaphlan4.loc[:,IBDMDB_metaphlan4.columns.str.startswith('s__')].T
IBDMDB_Hierarchical = IBDMDB_metaphlan4.join(IBDMDB_Hierarchical)

IBDMDB_Hierarchical
# Out:
#                                     HSM7J4HC  HSM7J4LD  MSM79H83  MSM6J2PO  \
# Abundance
# s__Phocaeicola_vulgatus             23.17456  25.69161   0.00157  15.87511
# s__Phocaeicola_massiliensis         20.69844   0.00000   0.00000   0.00000
# s__Prevotella_copri_clade_A         16.81446   0.00692   0.00000   0.00000
# s__Alistipes_putredinis              5.02926   0.00000   3.84064   0.54406
# s__Faecalibacterium_prausnitzii      3.82975   0.00000   6.22134  18.64314
# ...                                      ...       ...       ...       ...
# s__Schaalia_turicensis                   NaN       NaN       NaN       NaN
# s__Bacteroidales_bacterium_KA00251       NaN       NaN       NaN       NaN
# s__Parvimonas_sp_KA00067                 NaN       NaN       NaN       NaN
# s__Urmitella_timonensis                  NaN       NaN       NaN       NaN
# s__GGB1455_SGB2018                       NaN       NaN       NaN       NaN
#
#                                     CSMA8M9R  MSM9VZMU  MSM79H6D  PSMA265D  \
# Abundance
# s__Phocaeicola_vulgatus             11.51861   5.81560   5.65375   0.00000
# s__Phocaeicola_massiliensis          5.23714   3.82368   4.33952   0.00000
# s__Prevotella_copri_clade_A          0.00000   0.00000  11.96415   0.00000
# s__Alistipes_putredinis              2.61263   5.37161   1.80868   0.00000
# s__Faecalibacterium_prausnitzii      2.55939   6.27643   2.34273  40.53848
# ...                                      ...       ...       ...       ...
# s__Schaalia_turicensis                   NaN       NaN       NaN       NaN
# s__Bacteroidales_bacterium_KA00251       NaN       NaN       NaN       NaN
# s__Parvimonas_sp_KA00067                 NaN       NaN       NaN       NaN
# s__Urmitella_timonensis                  NaN       NaN       NaN       NaN
# s__GGB1455_SGB2018                       NaN       NaN       NaN       NaN
#
#                                     MSM6J2HR  MSM9VZGY  ...  HSM67VG8  \
# Abundance                                               ...
# s__Phocaeicola_vulgatus             25.58722   0.00000  ...   8.03243
# s__Phocaeicola_massiliensis          0.00000   2.85065  ...   0.00000
# s__Prevotella_copri_clade_A          0.00000   0.00000  ...   0.00000
# s__Alistipes_putredinis              5.14192   2.33574  ...   2.92598
# s__Faecalibacterium_prausnitzii      3.46521   9.78696  ...   1.72562
# ...                                      ...       ...  ...       ...
# s__Schaalia_turicensis                   NaN       NaN  ...       NaN
# s__Bacteroidales_bacterium_KA00251       NaN       NaN  ...       NaN
# s__Parvimonas_sp_KA00067                 NaN       NaN  ...       NaN
# s__Urmitella_timonensis                  NaN       NaN  ...       NaN
# s__GGB1455_SGB2018                       NaN       NaN  ...       NaN
#
#                                     HSM67VEO  HSM67VI3  HSM7J4R2  MSMA26BL  \
# Abundance
# s__Phocaeicola_vulgatus              0.00000  29.88947   0.00000   7.85503
# s__Phocaeicola_massiliensis          0.00000   0.00000  31.95659   3.00841
# s__Prevotella_copri_clade_A          0.00000   0.00000   0.00000   0.00000
# s__Alistipes_putredinis              3.81422   7.78165   0.00000   2.76951
# s__Faecalibacterium_prausnitzii      4.86957   3.48448  12.80999  14.87397
# ...                                      ...       ...       ...       ...
# s__Schaalia_turicensis                   NaN       NaN       NaN       NaN
# s__Bacteroidales_bacterium_KA00251       NaN       NaN       NaN       NaN
# s__Parvimonas_sp_KA00067                 NaN       NaN       NaN       NaN
# s__Urmitella_timonensis                  NaN       NaN       NaN       NaN
# s__GGB1455_SGB2018                       NaN       NaN       NaN       NaN
#
#                                     MSM79H9A  HSM7J4KK  MSM79HC4  HSM7J4G1  \
# Abundance
# s__Phocaeicola_vulgatus              1.31148  14.84775   7.12941   0.09671
# s__Phocaeicola_massiliensis          0.00000   6.85684   0.00000   0.00000
# s__Prevotella_copri_clade_A          0.00000   1.01704   0.00000   0.09925
# s__Alistipes_putredinis              2.89840   3.55767   0.36777   1.07894
# s__Faecalibacterium_prausnitzii      0.19539   2.96621  18.03702   2.26761
# ...                                      ...       ...       ...       ...
# s__Schaalia_turicensis                   NaN       NaN       NaN   0.03889
# s__Bacteroidales_bacterium_KA00251       NaN       NaN       NaN   0.02447
# s__Parvimonas_sp_KA00067                 NaN       NaN       NaN   0.01544
# s__Urmitella_timonensis                  NaN       NaN       NaN   0.01081
# s__GGB1455_SGB2018                       NaN       NaN       NaN   0.00476
#
#                                                                                     0
# Abundance
# s__Phocaeicola_vulgatus             k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Phocaeicola_massiliensis         k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Prevotella_copri_clade_A         k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Alistipes_putredinis             k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Faecalibacterium_prausnitzii     k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...
# ...                                                                               ...
# s__Schaalia_turicensis              k__Bacteria|p__Actinobacteria|c__Actinobacteri...
# s__Bacteroidales_bacterium_KA00251  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...
# s__Parvimonas_sp_KA00067            k__Bacteria|p__Firmicutes|c__Tissierellia|o__T...
# s__Urmitella_timonensis             k__Bacteria|p__Firmicutes|c__Tissierellia|o__T...
# s__GGB1455_SGB2018                  k__Bacteria|p__Bacteroidetes|c__CFGB618|o__OFG...
#
# [863 rows x 364 columns]

# %%
def species_factor (df, project_name):
    df['Hierarchical'] = df['0'].apply(lambda x: x.split("|")[5] if isinstance(x, str) else [])
    df['counts'] = df['Hierarchical'].map(df['Hierarchical'].value_counts())
    df.insert((len(df.columns)-3),'counts',df.pop('counts'))
    df = df.iloc[:,0:-2].apply(lambda row: row * row['counts'], axis=1)
    df = df.drop(['counts'],axis = 1).T
    df['Type'] = project_name
    return df

# %%
MetaHit = species_factor(MetaHit_Hierarchical, 'MetaHit')
MetaHit
# Out:
# Abundance    s__Phocaeicola_plebeius  s__Ruminococcus_bicirculans  \
# SAMEA728920                  0.00000                      1.74834
# SAMEA728635                  0.00000                      0.00000
# SAMEA728854                  0.00000                      0.00000
# SAMEA728867                  0.00000                      0.00000
# SAMEA728745                  0.00000                      0.23508
# ...                              ...                          ...
# SAMEA728661                 65.25132                      4.17402
# SAMEA728723                  0.00000                     19.00161
# SAMEA728894                 21.70704                      0.00000
# SAMEA728772                 34.70556                      4.40064
# SAMEA728899                  0.00000                      0.76482
#
# Abundance    s__Eubacterium_rectale  s__Bacteroides_uniformis  \
# SAMEA728920                  8.2368                   2.66688
# SAMEA728635                295.7972                 413.82432
# SAMEA728854                  2.0386                 292.45776
# SAMEA728867                 56.4990                  52.03920
# SAMEA728745                 31.8344                   4.85952
# ...                             ...                       ...
# SAMEA728661                  7.9296                 152.72736
# SAMEA728723                 11.6584                 156.90384
# SAMEA728894                 61.1654                  30.44832
# SAMEA728772                 25.4560                 217.49328
# SAMEA728899                  1.6248                  40.94784
#
# Abundance    s__Roseburia_faecis  s__Clostridia_unclassified_SGB4367  \
# SAMEA728920             63.66564                             3.45786
# SAMEA728635             33.66708                             0.00000
# SAMEA728854              3.65028                             0.00000
# SAMEA728867             21.94632                             0.00000
# SAMEA728745             23.54772                            28.70322
# ...                          ...                                 ...
# SAMEA728661              4.20228                             0.00000
# SAMEA728723              5.49132                             0.00000
# SAMEA728894              0.00000                             0.00000
# SAMEA728772             23.16912                           136.12536
# SAMEA728899              1.01304                             0.00000
#
# Abundance    s__Ruminococcus_bromii  s__Phocaeicola_dorei  \
# SAMEA728920                13.12191               0.00000
# SAMEA728635                 0.00000              10.65240
# SAMEA728854                25.76061               6.25164
# SAMEA728867                12.54528              14.62788
# SAMEA728745                 1.34496               0.00000
# ...                             ...                   ...
# SAMEA728661                 0.00000               4.90344
# SAMEA728723                 0.00000              24.48648
# SAMEA728894                 0.00000               0.00000
# SAMEA728772                59.52303               0.00000
# SAMEA728899                 0.00000               0.00000
#
# Abundance    s__Alistipes_putredinis  s__Faecalibacterium_prausnitzii  ...  \
# SAMEA728920                 13.06620                          5.32839  ...
# SAMEA728635                 35.08197                          3.27201  ...
# SAMEA728854                  0.00000                          8.13588  ...
# SAMEA728867                  8.59362                          6.32166  ...
# SAMEA728745                  1.86123                          3.43878  ...
# ...                              ...                              ...  ...
# SAMEA728661                 60.14694                         13.82784  ...
# SAMEA728723                 72.40674                          7.63416  ...
# SAMEA728894                 37.70781                          2.55021  ...
# SAMEA728772                 52.70160                          5.33772  ...
# SAMEA728899                 14.14140                          1.58382  ...
#
# Abundance    s__GGB13083_SGB20273  s__GGB9686_SGB15190  \
# SAMEA728920                   NaN                  NaN
# SAMEA728635                   NaN                  NaN
# SAMEA728854                   NaN                  NaN
# SAMEA728867                   NaN                  NaN
# SAMEA728745                   NaN                  NaN
# ...                           ...                  ...
# SAMEA728661                   NaN                  NaN
# SAMEA728723                   NaN                  NaN
# SAMEA728894                   NaN                  NaN
# SAMEA728772                   NaN                  NaN
# SAMEA728899                   NaN                  NaN
#
# Abundance    s__Lelliottia_amnigena  s__Raoultella_ornithinolytica  \
# SAMEA728920                     NaN                            NaN
# SAMEA728635                     NaN                            NaN
# SAMEA728854                     NaN                            NaN
# SAMEA728867                     NaN                            NaN
# SAMEA728745                     NaN                            NaN
# ...                             ...                            ...
# SAMEA728661                     NaN                            NaN
# SAMEA728723                     NaN                            NaN
# SAMEA728894                     NaN                            NaN
# SAMEA728772                     NaN                            NaN
# SAMEA728899                     NaN                            NaN
#
# Abundance    s__Kosakonia_cowanii  s__Klebsiella_oxytoca  \
# SAMEA728920                   NaN                    NaN
# SAMEA728635                   NaN                    NaN
# SAMEA728854                   NaN                    NaN
# SAMEA728867                   NaN                    NaN
# SAMEA728745                   NaN                    NaN
# ...                           ...                    ...
# SAMEA728661                   NaN                    NaN
# SAMEA728723                   NaN                    NaN
# SAMEA728894                   NaN                    NaN
# SAMEA728772                   NaN                    NaN
# SAMEA728899                   NaN                    NaN
#
# Abundance    s__GGB14014_SGB21441  s__Enterobacter_huaxiensis  \
# SAMEA728920                   NaN                         NaN
# SAMEA728635                   NaN                         NaN
# SAMEA728854                   NaN                         NaN
# SAMEA728867                   NaN                         NaN
# SAMEA728745                   NaN                         NaN
# ...                           ...                         ...
# SAMEA728661                   NaN                         NaN
# SAMEA728723                   NaN                         NaN
# SAMEA728894                   NaN                         NaN
# SAMEA728772                   NaN                         NaN
# SAMEA728899                   NaN                         NaN
#
# Abundance    s__Sutterella_megalosphaeroides     Type
# SAMEA728920                              NaN  MetaHit
# SAMEA728635                              NaN  MetaHit
# SAMEA728854                              NaN  MetaHit
# SAMEA728867                              NaN  MetaHit
# SAMEA728745                              NaN  MetaHit
# ...                                      ...      ...
# SAMEA728661                              NaN  MetaHit
# SAMEA728723                              NaN  MetaHit
# SAMEA728894                              NaN  MetaHit
# SAMEA728772                              NaN  MetaHit
# SAMEA728899                              NaN  MetaHit
#
# [99 rows x 1427 columns]

# %%
IBDMDB = species_factor(IBDMDB_Hierarchical, 'IBDMDB')

# %%
MI_species = pd.concat([IBDMDB,MetaHit])
MI_species.insert((len(MI_species.columns)-1),'Type',MI_species.pop('Type'))
MI_species = MI_species.fillna(0)
# Out:
# /var/folders/qz/fy7nnm954f76spkqc86w7g_c0000gn/T/ipykernel_18267/595237669.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   MI_species.insert((len(MI_species.columns)-1),'Type',MI_species.pop('Type'))

# %%
Feature = MI_species.iloc[:,:-1]
Target = MI_species.loc[:,MI_species.columns == 'Type']

# %%
pca = PCA(n_components=3).fit(Feature)
X_pca = pca.transform(Feature)
n_pcs = pca.components_.shape[0]

# get the index of the most important feature on EACH component
# LIST COMPREHENSION HERE
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = list(Feature.columns)
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
print(most_important_names)
# LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df = pd.DataFrame(sorted(dic.items()))
df
# Out:
# ['s__Prevotella_copri_clade_A', 's__Bacteroides_stercoris', 's__Bacteroides_uniformis']
#      0                            1
# 0  PC1  s__Prevotella_copri_clade_A
# 1  PC2     s__Bacteroides_stercoris
# 2  PC3     s__Bacteroides_uniformis

# %%
sns.lineplot(y=pca.explained_variance_ratio_ ,x=range(1,4))
pca.explained_variance_ratio_
# Out:
# array([0.45896128, 0.17370321, 0.07259152])

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.title("PCA")
sns.scatterplot(X_pca[:,0],X_pca[:,1], hue= Target['Type'])
plt.subplot(1,3,2)
plt.xlabel("PC 2")
plt.ylabel("PC 3")
plt.title("PCA")
sns.scatterplot(X_pca[:,1],X_pca[:,2], hue= Target['Type'])
plt.subplot(1,3,3)
plt.xlabel("PC 1")
plt.ylabel("PC 3")
plt.title("PCA")
sns.scatterplot(X_pca[:,0],X_pca[:,2], hue= Target['Type'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
model = TSNE(learning_rate=1, random_state=1)

# Apply fit_transform to normalized_movements: tsne_features
Cluster_Species_Pheno = [Feature]
for pheno in Cluster_Species_Pheno:
    tsne_features = model.fit_transform(pheno)

    # Select the 0th feature: xs
    xs = tsne_features[:, 0]

    # Select the 1st feature: ys
    ys = tsne_features[:, 1]

    # Scatter plot
    plt.figure(figsize=(16, 9))
    plt.scatter(xs, ys, alpha=0.5)

    # Annotate the points
    for x, y, company in zip(xs, ys, Target['Type']):
        plt.annotate(company, (x, y), fontsize=10, alpha=0.75)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
