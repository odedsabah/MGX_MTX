# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import pairwise_distances
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
import random
from sklearn.cluster import AgglomerativeClustering
from sklearn import metrics
import statsmodels.stats.multitest as mc
from scipy.stats import hypergeom

# %%
CD = pd.read_csv('~/Desktop/Metaphlan4_MGX_CD.csv').set_index('Abundance').T
UC = pd.read_csv('~/Desktop/Metaphlan4_MGX_UC.csv').set_index('Abundance').T
Control = pd.read_csv('~/Desktop/Metaphlan4_MGX_Control.csv').set_index('Abundance').T

# %%
CD['diagnosis'] = 'CD'
UC['diagnosis'] = 'UC'
Control['diagnosis'] = 'Control'
Metaphlan4 = pd.concat([CD,UC,Control])
Metaphlan4
# Out:
# Abundance  k__Bacteria  p__Firmicutes  p__Bacteroidetes  p__Proteobacteria  \
# PSM7J14T     100.00000       71.02855          26.85212            1.89661
# CSM79HOL     100.00000       34.80297          63.49096            1.49113
# CSM67U9D     100.00000       54.68728          44.23327            0.82266
# MSM6J2MF     100.00000       96.47442           0.24335            3.10878
# HSM7J4N4     100.00000       27.30707          71.32484            1.35394
# ...                ...            ...               ...                ...
# MSMA26BL     100.00000       36.18427          61.89923            1.72077
# MSM79H9A      99.84673       36.69046          58.88541            0.98279
# HSM7J4KK     100.00000       33.89929          62.37670            1.84729
# MSM79HC4     100.00000       80.54021          16.09695            0.89052
# HSM7J4G1     100.00000       33.42414          65.48134            0.77557
#
# Abundance  p__Actinobacteria  c__Clostridia  c__Bacteroidia  c__Negativicutes  \
# PSM7J14T             0.22272       55.95542        26.85212          12.28881
# CSM79HOL             0.21495       30.54465        63.49096           2.56962
# CSM67U9D             0.25679       50.51548        44.23327           2.28682
# MSM6J2MF             0.16437       82.71787         0.24335          13.23502
# HSM7J4N4             0.01415       25.32084        71.32484           1.39104
# ...                      ...            ...             ...               ...
# MSMA26BL             0.19572       34.43199        61.89923           1.54756
# MSM79H9A             0.58879       33.53007        58.88541           0.38769
# HSM7J4KK             0.81156       31.61819        62.23758           0.55590
# MSM79HC4             0.68033       75.44387        16.09695           3.38109
# HSM7J4G1             0.23973       30.90241        65.47409           1.49743
#
# Abundance  c__Firmicutes_unclassified  c__Betaproteobacteria  ...  \
# PSM7J14T                      2.64634                0.98112  ...
# CSM79HOL                      0.32024                1.44817  ...
# CSM67U9D                      0.51562                0.73302  ...
# MSM6J2MF                      0.00000                0.00000  ...
# HSM7J4N4                      0.44382                0.01219  ...
# ...                               ...                    ...  ...
# MSMA26BL                      0.03789                1.05422  ...
# MSM79H9A                      0.00567                0.04974  ...
# HSM7J4KK                      0.16380                0.93262  ...
# MSM79HC4                      1.36633                0.73091  ...
# HSM7J4G1                      0.21606                0.09251  ...
#
# Abundance  t__SGB47522  g__GGB3171  s__GGB3171_SGB4185  t__SGB4185  \
# PSM7J14T           NaN         NaN                 NaN         NaN
# CSM79HOL           NaN         NaN                 NaN         NaN
# CSM67U9D           NaN         NaN                 NaN         NaN
# MSM6J2MF           NaN         NaN                 NaN         NaN
# HSM7J4N4           NaN         NaN                 NaN         NaN
# ...                ...         ...                 ...         ...
# MSMA26BL           0.0         0.0                 0.0         0.0
# MSM79H9A           0.0         0.0                 0.0         0.0
# HSM7J4KK           0.0         0.0                 0.0         0.0
# MSM79HC4           0.0         0.0                 0.0         0.0
# HSM7J4G1           0.0         0.0                 0.0         0.0
#
# Abundance  s__Slackia_piriformis  t__SGB14779  \
# PSM7J14T                     NaN          NaN
# CSM79HOL                     NaN          NaN
# CSM67U9D                     NaN          NaN
# MSM6J2MF                     NaN          NaN
# HSM7J4N4                     NaN          NaN
# ...                          ...          ...
# MSMA26BL                     NaN          NaN
# MSM79H9A                     NaN          NaN
# HSM7J4KK                 0.00439      0.00439
# MSM79HC4                 0.00000      0.00000
# HSM7J4G1                 0.00000      0.00000
#
# Abundance  s__Bacteroidales_bacterium_KA00251  s__Parvimonas_sp_KA00067  \
# PSM7J14T                                  NaN                       NaN
# CSM79HOL                                  NaN                       NaN
# CSM67U9D                                  NaN                       NaN
# MSM6J2MF                                  NaN                       NaN
# HSM7J4N4                                  NaN                       NaN
# ...                                       ...                       ...
# MSMA26BL                                  NaN                       NaN
# MSM79H9A                                  NaN                       NaN
# HSM7J4KK                                  NaN                       NaN
# MSM79HC4                                  NaN                       NaN
# HSM7J4G1                              0.02447                   0.01544
#
# Abundance  t__SGB3324  t__SGB6648
# PSM7J14T          NaN         NaN
# CSM79HOL          NaN         NaN
# CSM67U9D          NaN         NaN
# MSM6J2MF          NaN         NaN
# HSM7J4N4          NaN         NaN
# ...               ...         ...
# MSMA26BL          NaN         NaN
# MSM79H9A          NaN         NaN
# HSM7J4KK          NaN         NaN
# MSM79HC4          NaN         NaN
# HSM7J4G1      0.02447     0.01544
#
# [1337 rows x 3773 columns]

# %%
select_sampels = pd.read_csv('~/Desktop/selected_samples_MGX.csv')
select_sampels = select_sampels.set_index('External ID')
select_sampels.drop("Participant ID", inplace=True, axis=1)

# %%
Metaphlan4 = Metaphlan4.loc[select_sampels.index,:]
Metaphlan4 = Metaphlan4.loc[:,Metaphlan4.columns.str.startswith('s__')]
Metaphlan4["diagnosis"] = select_sampels.iloc[:,-1]
# Metaphlan4.reset_index(inplace=True)
Metaphlan4
# Out:
# Abundance    s__Phocaeicola_vulgatus  s__Eubacterium_rectale  \
# External ID
# CSM67UA2                    36.02530                 0.00000
# CSM5MCVN                    51.31297                 0.95498
# CSM67UBZ                     0.00313                 0.00000
# CSM5MCXL                    32.29455                 3.46622
# CSM5MCY8                     0.00000                 0.56787
# ...                              ...                     ...
# PSM7J19N                     5.47393                 1.38623
# PSM6XBW3                     0.00000                 0.00000
# PSM7J12J                     0.00515                 0.00000
# PSM7J1BX                    11.31998                 0.00000
# PSMA264O                     8.33563                 0.19689
#
# Abundance    s__Dialister_invisus  s__Roseburia_faecis  \
# External ID
# CSM67UA2                  1.91898              1.34449
# CSM5MCVN                  1.54371              0.04588
# CSM67UBZ                  0.00000              0.00000
# CSM5MCXL                  0.00000              0.00000
# CSM5MCY8                  0.00000              0.00000
# ...                           ...                  ...
# PSM7J19N                  0.00000              0.02240
# PSM6XBW3                  0.00000              0.00000
# PSM7J12J                  0.00000              0.00000
# PSM7J1BX                  0.00000              0.00000
# PSMA264O                  0.79575              2.98076
#
# Abundance    s__Roseburia_inulinivorans  s__Faecalibacterium_prausnitzii  \
# External ID
# CSM67UA2                        0.03810                          0.90627
# CSM5MCVN                        0.00000                          0.00000
# CSM67UBZ                        0.00000                         10.84042
# CSM5MCXL                        0.71850                          2.63304
# CSM5MCY8                        0.30914                          2.20589
# ...                                 ...                              ...
# PSM7J19N                        0.60937                          4.65083
# PSM6XBW3                        0.00000                          0.00000
# PSM7J12J                        0.00000                          0.00000
# PSM7J1BX                        0.01503                          9.45264
# PSMA264O                        0.95547                         13.34191
#
# Abundance    s__Bacteroides_xylanisolvens  s__Firmicutes_bacterium_AF16_15  \
# External ID
# CSM67UA2                          0.00000                          0.00000
# CSM5MCVN                          7.95270                          0.00000
# CSM67UBZ                          1.39625                          0.00000
# CSM5MCXL                          0.00904                          0.00000
# CSM5MCY8                          0.00000                          0.00000
# ...                                   ...                              ...
# PSM7J19N                          0.00000                          0.71590
# PSM6XBW3                          0.00000                          0.00000
# PSM7J12J                          0.00000                          0.00000
# PSM7J1BX                          0.02448                          0.00000
# PSMA264O                          0.12200                          0.05702
#
# Abundance    s__Bacteroides_uniformis  s__Ruminococcus_bromii  ...  \
# External ID                                                    ...
# CSM67UA2                     17.15467                 0.00000  ...
# CSM5MCVN                      0.00000                 0.00000  ...
# CSM67UBZ                     16.65207                 1.02143  ...
# CSM5MCXL                     12.83634                 0.12034  ...
# CSM5MCY8                      8.33000                 0.22200  ...
# ...                               ...                     ...  ...
# PSM7J19N                      4.14365                 0.00000  ...
# PSM6XBW3                      0.00000                 0.00000  ...
# PSM7J12J                      0.00000                 0.00000  ...
# PSM7J1BX                      4.53008                 0.00000  ...
# PSMA264O                      1.27741                 0.00000  ...
#
# Abundance    s__Streptococcus_agalactiae  s__Faecalicoccus_pleomorphus  \
# External ID
# CSM67UA2                             NaN                           NaN
# CSM5MCVN                             NaN                           NaN
# CSM67UBZ                             NaN                           NaN
# CSM5MCXL                             NaN                           NaN
# CSM5MCY8                             NaN                           NaN
# ...                                  ...                           ...
# PSM7J19N                             0.0                           0.0
# PSM6XBW3                             0.0                           0.0
# PSM7J12J                             NaN                           NaN
# PSM7J1BX                             NaN                           NaN
# PSMA264O                             NaN                           NaN
#
# Abundance    s__Streptococcus_dysgalactiae  s__Corynebacterium_accolens  \
# External ID
# CSM67UA2                               NaN                          NaN
# CSM5MCVN                               NaN                          NaN
# CSM67UBZ                               NaN                          NaN
# CSM5MCXL                               NaN                          NaN
# CSM5MCY8                               NaN                          NaN
# ...                                    ...                          ...
# PSM7J19N                               0.0                          0.0
# PSM6XBW3                               0.0                          0.0
# PSM7J12J                               NaN                          NaN
# PSM7J1BX                               NaN                          NaN
# PSMA264O                               NaN                          NaN
#
# Abundance    s__GGB39918_SGB47522  s__GGB3171_SGB4185  s__Slackia_piriformis  \
# External ID
# CSM67UA2                      NaN                 NaN                    NaN
# CSM5MCVN                      NaN                 NaN                    NaN
# CSM67UBZ                      NaN                 NaN                    NaN
# CSM5MCXL                      NaN                 NaN                    NaN
# CSM5MCY8                      NaN                 NaN                    NaN
# ...                           ...                 ...                    ...
# PSM7J19N                      0.0                 NaN                    NaN
# PSM6XBW3                      0.0                 NaN                    NaN
# PSM7J12J                      NaN                 NaN                    NaN
# PSM7J1BX                      NaN                 NaN                    NaN
# PSMA264O                      NaN                 NaN                    NaN
#
# Abundance    s__Bacteroidales_bacterium_KA00251  s__Parvimonas_sp_KA00067  \
# External ID
# CSM67UA2                                    NaN                       NaN
# CSM5MCVN                                    NaN                       NaN
# CSM67UBZ                                    NaN                       NaN
# CSM5MCXL                                    NaN                       NaN
# CSM5MCY8                                    NaN                       NaN
# ...                                         ...                       ...
# PSM7J19N                                    NaN                       NaN
# PSM6XBW3                                    NaN                       NaN
# PSM7J12J                                    NaN                       NaN
# PSM7J1BX                                    NaN                       NaN
# PSMA264O                                    NaN                       NaN
#
# Abundance    diagnosis
# External ID
# CSM67UA2            CD
# CSM5MCVN            CD
# CSM67UBZ            UC
# CSM5MCXL            UC
# CSM5MCY8            UC
# ...                ...
# PSM7J19N        nonIBD
# PSM6XBW3        nonIBD
# PSM7J12J            CD
# PSM7J1BX            UC
# PSMA264O            UC
#
# [83 rows x 1219 columns]

# %%
M_CD_B = Metaphlan4[Metaphlan4['diagnosis'] == "CD"].drop("diagnosis",axis=1)
M_UC_B = Metaphlan4[Metaphlan4['diagnosis'] == "UC"].drop("diagnosis",axis=1)
M_Control_B = Metaphlan4[Metaphlan4['diagnosis'] == "nonIBD"].drop("diagnosis",axis=1)
M_CD_B
# Out:
# Abundance    s__Phocaeicola_vulgatus  s__Eubacterium_rectale  \
# External ID
# CSM67UA2                    36.02530                 0.00000
# CSM5MCVN                    51.31297                 0.95498
# CSM5MCZ3                     0.00000                 0.00000
# CSM5MCWE                     0.00000                 0.00000
# CSM67UCK                    14.39624                 0.00000
# CSM5MCZF                    16.56186                 5.87824
# CSM67UB1                    26.28361                 0.05007
# CSM67UBB                     0.00359                 0.17720
# CSM79HH8                     7.72936                 0.48122
# CSM79HJM                    39.03332                 3.00252
# CSM79HNU                     0.09592                 0.00000
# ESM5MEDN                     0.00000                 1.19774
# ESM718V8                     2.05774                 1.28534
# HSM5FZBZ                     5.63537                 8.08048
# HSM5MD4Y                     1.45111                 0.00000
# HSM5MD7O                     0.00000                 0.00000
# HSM5MD4O                    35.61249                 2.40474
# HSM5MD6A                    24.81194                 2.44005
# HSM5MD62                    28.56918                 0.00000
# HSM67VIF                     3.30668                 0.03593
# HSM7CZ3G                    29.37209                 1.30799
# HSM7J4Q7                     0.00000                 4.62402
# MSM5LLDI                     0.00000                 0.56703
# MSM5LLGL                    35.87378                 2.34160
# MSM6J2LT                    18.72266                 0.00000
# MSM6J2J5                    15.17948                 0.89608
# MSM6J2KE                     1.49230                 0.20515
# MSM6J2IG                    14.47695                 0.54162
# MSM5LLF4                     0.00000                 0.00000
# MSM79HDQ                    29.20308                 0.00000
# MSM9VZPL                     0.02092                 4.11391
# PSM6XBQY                    20.45148                 1.76390
# PSM6XBRK                    32.60320                 1.58982
# PSM6XBSI                    15.89865                 1.90643
# PSM7J19F                    37.57222                 0.00000
# PSM7J12J                     0.00515                 0.00000
#
# Abundance    s__Dialister_invisus  s__Roseburia_faecis  \
# External ID
# CSM67UA2                  1.91898              1.34449
# CSM5MCVN                  1.54371              0.04588
# CSM5MCZ3                  0.00000              0.30479
# CSM5MCWE                  0.00000              0.77226
# CSM67UCK                  0.00000              0.50987
# CSM5MCZF                  0.00000              3.77646
# CSM67UB1                  0.98187              0.03832
# CSM67UBB                  0.00000              0.00000
# CSM79HH8                  0.00000              0.00000
# CSM79HJM                  0.00000              0.00000
# CSM79HNU                  0.00000              0.19964
# ESM5MEDN                  0.00000              0.16292
# ESM718V8                  0.00000              1.39700
# HSM5FZBZ                  0.22032              0.00000
# HSM5MD4Y                  0.64785              0.01679
# HSM5MD7O                  0.00000              0.00000
# HSM5MD4O                  0.57063              0.00000
# HSM5MD6A                  5.75181              0.11648
# HSM5MD62                  0.85628              0.00000
# HSM67VIF                  0.00000              0.02851
# HSM7CZ3G                  0.00000              0.00000
# HSM7J4Q7                  0.23401              0.99699
# MSM5LLDI                  0.54286              0.00000
# MSM5LLGL                  0.27686              0.57823
# MSM6J2LT                  1.03097              0.00000
# MSM6J2J5                  1.86381              0.88081
# MSM6J2KE                  0.00000              1.54246
# MSM6J2IG                  0.00000              4.93917
# MSM5LLF4                  0.00000             19.75146
# MSM79HDQ                  0.00000              0.00000
# MSM9VZPL                  1.25877              3.68510
# PSM6XBQY                  0.16009              0.00000
# PSM6XBRK                  0.00000              1.26683
# PSM6XBSI                  0.18746              0.24518
# PSM7J19F                  0.00000              0.00000
# PSM7J12J                  0.00000              0.00000
#
# Abundance    s__Roseburia_inulinivorans  s__Faecalibacterium_prausnitzii  \
# External ID
# CSM67UA2                        0.03810                          0.90627
# CSM5MCVN                        0.00000                          0.00000
# CSM5MCZ3                        0.19031                          0.00000
# CSM5MCWE                        0.00000                          0.00000
# CSM67UCK                        0.00000                         16.62301
# CSM5MCZF                        0.69644                         18.24435
# CSM67UB1                        0.01534                          4.02696
# CSM67UBB                        0.00000                          7.61430
# CSM79HH8                        0.00000                          0.01443
# CSM79HJM                        0.05448                          0.67430
# CSM79HNU                        0.00000                          0.00000
# ESM5MEDN                        0.00000                          6.40549
# ESM718V8                        0.02935                          4.52068
# HSM5FZBZ                        0.00000                          1.98399
# HSM5MD4Y                        0.29414                          0.00000
# HSM5MD7O                        0.00000                          0.00000
# HSM5MD4O                        0.00483                         11.89511
# HSM5MD6A                        0.22601                          1.89330
# HSM5MD62                        0.05517                          6.66227
# HSM67VIF                        0.00000                          4.40763
# HSM7CZ3G                        0.01045                          3.64456
# HSM7J4Q7                        0.02202                          7.06983
# MSM5LLDI                        0.00000                          1.60476
# MSM5LLGL                        0.00673                         13.39956
# MSM6J2LT                        0.00000                          7.24944
# MSM6J2J5                        0.15789                          5.83873
# MSM6J2KE                        0.13892                          3.87067
# MSM6J2IG                        0.03403                          0.55512
# MSM5LLF4                        0.00000                          0.00000
# MSM79HDQ                        0.00000                         11.77528
# MSM9VZPL                        0.14208                         34.53047
# PSM6XBQY                        0.00000                          4.41120
# PSM6XBRK                        0.53729                          1.48224
# PSM6XBSI                        0.00000                          5.57896
# PSM7J19F                        0.00000                          6.03691
# PSM7J12J                        0.00000                          0.00000
#
# Abundance    s__Bacteroides_xylanisolvens  s__Firmicutes_bacterium_AF16_15  \
# External ID
# CSM67UA2                          0.00000                          0.00000
# CSM5MCVN                          7.95270                          0.00000
# CSM5MCZ3                          0.00000                          0.00000
# CSM5MCWE                          0.00000                          0.00000
# CSM67UCK                          1.25564                          0.00000
# CSM5MCZF                          0.00000                          0.08565
# CSM67UB1                          2.37736                          0.00000
# CSM67UBB                          2.65299                          0.16354
# CSM79HH8                          2.64679                          0.00000
# CSM79HJM                          1.25563                          0.00000
# CSM79HNU                          0.02765                          0.00000
# ESM5MEDN                          0.41111                          0.12416
# ESM718V8                          0.19722                          0.27527
# HSM5FZBZ                          2.11302                          0.00000
# HSM5MD4Y                          0.00000                          0.00000
# HSM5MD7O                          0.00000                          0.00000
# HSM5MD4O                          2.76818                          0.04484
# HSM5MD6A                         12.69979                          0.00000
# HSM5MD62                          8.93874                          0.27158
# HSM67VIF                          0.84254                          0.39857
# HSM7CZ3G                          7.53147                          1.19365
# HSM7J4Q7                          0.10088                          2.13980
# MSM5LLDI                          2.32232                          0.00000
# MSM5LLGL                          0.00000                          0.00808
# MSM6J2LT                          0.02883                          0.00000
# MSM6J2J5                          3.26755                          0.04675
# MSM6J2KE                          0.09087                          0.05951
# MSM6J2IG                          0.03993                          0.00000
# MSM5LLF4                          0.00000                          0.00000
# MSM79HDQ                          0.01440                          0.02500
# MSM9VZPL                          0.01924                          0.02533
# PSM6XBQY                          6.25296                          0.00000
# PSM6XBRK                          0.33300                          0.94796
# PSM6XBSI                         14.41234                          0.00000
# PSM7J19F                          1.49219                          0.00000
# PSM7J12J                          0.00000                          0.00000
#
# Abundance    s__Bacteroides_uniformis  s__Ruminococcus_bromii  ...  \
# External ID                                                    ...
# CSM67UA2                     17.15467                 0.00000  ...
# CSM5MCVN                      0.00000                 0.00000  ...
# CSM5MCZ3                      0.00000                 0.00000  ...
# CSM5MCWE                      0.00000                 0.00000  ...
# CSM67UCK                      9.14593                 0.02199  ...
# CSM5MCZF                     18.67945                 0.55186  ...
# CSM67UB1                      2.38708                 0.09588  ...
# CSM67UBB                      0.00000                 0.93762  ...
# CSM79HH8                      4.68568                 0.00000  ...
# CSM79HJM                      0.00000                 0.00000  ...
# CSM79HNU                      0.02399                 0.00000  ...
# ESM5MEDN                      3.76609                 0.00000  ...
# ESM718V8                      0.48420                 0.02690  ...
# HSM5FZBZ                      0.98532                 0.00000  ...
# HSM5MD4Y                     22.69501                 0.00000  ...
# HSM5MD7O                      0.00000                 0.00000  ...
# HSM5MD4O                      3.22438                 0.00000  ...
# HSM5MD6A                      6.27291                 0.40230  ...
# HSM5MD62                     14.41137                 0.00000  ...
# HSM67VIF                      1.86097                 0.00000  ...
# HSM7CZ3G                     12.47467                 0.15495  ...
# HSM7J4Q7                      3.85020                 0.22085  ...
# MSM5LLDI                      0.00000                 0.00000  ...
# MSM5LLGL                      9.65608                 0.00000  ...
# MSM6J2LT                      3.43489                 0.00000  ...
# MSM6J2J5                      3.24812                 0.00000  ...
# MSM6J2KE                      0.82643                 0.02396  ...
# MSM6J2IG                     12.13869                 0.00000  ...
# MSM5LLF4                      0.00000                 0.00000  ...
# MSM79HDQ                      8.05264                 0.00000  ...
# MSM9VZPL                      8.39495                 0.00000  ...
# PSM6XBQY                     10.18532                 0.08070  ...
# PSM6XBRK                      7.69257                 0.00000  ...
# PSM6XBSI                     22.54550                 0.16601  ...
# PSM7J19F                      3.80780                 0.00000  ...
# PSM7J12J                      0.00000                 0.00000  ...
#
# Abundance    s__GGB2734_SGB3677  s__Streptococcus_agalactiae  \
# External ID
# CSM67UA2                    NaN                          NaN
# CSM5MCVN                    NaN                          NaN
# CSM5MCZ3                    NaN                          NaN
# CSM5MCWE                    NaN                          NaN
# CSM67UCK                    NaN                          NaN
# CSM5MCZF                    NaN                          NaN
# CSM67UB1                    NaN                          NaN
# CSM67UBB                    NaN                          NaN
# CSM79HH8                    NaN                          NaN
# CSM79HJM                    NaN                          NaN
# CSM79HNU                    NaN                          NaN
# ESM5MEDN                    NaN                          NaN
# ESM718V8                    NaN                          NaN
# HSM5FZBZ                    NaN                          NaN
# HSM5MD4Y                    NaN                          NaN
# HSM5MD7O                    NaN                          NaN
# HSM5MD4O                    NaN                          NaN
# HSM5MD6A                    NaN                          NaN
# HSM5MD62                    NaN                          NaN
# HSM67VIF                    NaN                          NaN
# HSM7CZ3G                    NaN                          NaN
# HSM7J4Q7                    NaN                          NaN
# MSM5LLDI                    NaN                          NaN
# MSM5LLGL                    NaN                          NaN
# MSM6J2LT                    NaN                          NaN
# MSM6J2J5                    NaN                          NaN
# MSM6J2KE                    NaN                          NaN
# MSM6J2IG                    NaN                          NaN
# MSM5LLF4                    NaN                          NaN
# MSM79HDQ                    NaN                          NaN
# MSM9VZPL                    NaN                          NaN
# PSM6XBQY                    NaN                          NaN
# PSM6XBRK                    NaN                          NaN
# PSM6XBSI                    NaN                          NaN
# PSM7J19F                    NaN                          NaN
# PSM7J12J                    NaN                          NaN
#
# Abundance    s__Faecalicoccus_pleomorphus  s__Streptococcus_dysgalactiae  \
# External ID
# CSM67UA2                              NaN                            NaN
# CSM5MCVN                              NaN                            NaN
# CSM5MCZ3                              NaN                            NaN
# CSM5MCWE                              NaN                            NaN
# CSM67UCK                              NaN                            NaN
# CSM5MCZF                              NaN                            NaN
# CSM67UB1                              NaN                            NaN
# CSM67UBB                              NaN                            NaN
# CSM79HH8                              NaN                            NaN
# CSM79HJM                              NaN                            NaN
# CSM79HNU                              NaN                            NaN
# ESM5MEDN                              NaN                            NaN
# ESM718V8                              NaN                            NaN
# HSM5FZBZ                              NaN                            NaN
# HSM5MD4Y                              NaN                            NaN
# HSM5MD7O                              NaN                            NaN
# HSM5MD4O                              NaN                            NaN
# HSM5MD6A                              NaN                            NaN
# HSM5MD62                              NaN                            NaN
# HSM67VIF                              NaN                            NaN
# HSM7CZ3G                              NaN                            NaN
# HSM7J4Q7                              NaN                            NaN
# MSM5LLDI                              NaN                            NaN
# MSM5LLGL                              NaN                            NaN
# MSM6J2LT                              NaN                            NaN
# MSM6J2J5                              NaN                            NaN
# MSM6J2KE                              NaN                            NaN
# MSM6J2IG                              NaN                            NaN
# MSM5LLF4                              NaN                            NaN
# MSM79HDQ                              NaN                            NaN
# MSM9VZPL                              NaN                            NaN
# PSM6XBQY                              NaN                            NaN
# PSM6XBRK                              NaN                            NaN
# PSM6XBSI                              NaN                            NaN
# PSM7J19F                              NaN                            NaN
# PSM7J12J                              NaN                            NaN
#
# Abundance    s__Corynebacterium_accolens  s__GGB39918_SGB47522  \
# External ID
# CSM67UA2                             NaN                   NaN
# CSM5MCVN                             NaN                   NaN
# CSM5MCZ3                             NaN                   NaN
# CSM5MCWE                             NaN                   NaN
# CSM67UCK                             NaN                   NaN
# CSM5MCZF                             NaN                   NaN
# CSM67UB1                             NaN                   NaN
# CSM67UBB                             NaN                   NaN
# CSM79HH8                             NaN                   NaN
# CSM79HJM                             NaN                   NaN
# CSM79HNU                             NaN                   NaN
# ESM5MEDN                             NaN                   NaN
# ESM718V8                             NaN                   NaN
# HSM5FZBZ                             NaN                   NaN
# HSM5MD4Y                             NaN                   NaN
# HSM5MD7O                             NaN                   NaN
# HSM5MD4O                             NaN                   NaN
# HSM5MD6A                             NaN                   NaN
# HSM5MD62                             NaN                   NaN
# HSM67VIF                             NaN                   NaN
# HSM7CZ3G                             NaN                   NaN
# HSM7J4Q7                             NaN                   NaN
# MSM5LLDI                             NaN                   NaN
# MSM5LLGL                             NaN                   NaN
# MSM6J2LT                             NaN                   NaN
# MSM6J2J5                             NaN                   NaN
# MSM6J2KE                             NaN                   NaN
# MSM6J2IG                             NaN                   NaN
# MSM5LLF4                             NaN                   NaN
# MSM79HDQ                             NaN                   NaN
# MSM9VZPL                             NaN                   NaN
# PSM6XBQY                             NaN                   NaN
# PSM6XBRK                             NaN                   NaN
# PSM6XBSI                             NaN                   NaN
# PSM7J19F                             NaN                   NaN
# PSM7J12J                             NaN                   NaN
#
# Abundance    s__GGB3171_SGB4185  s__Slackia_piriformis  \
# External ID
# CSM67UA2                    NaN                    NaN
# CSM5MCVN                    NaN                    NaN
# CSM5MCZ3                    NaN                    NaN
# CSM5MCWE                    NaN                    NaN
# CSM67UCK                    NaN                    NaN
# CSM5MCZF                    NaN                    NaN
# CSM67UB1                    NaN                    NaN
# CSM67UBB                    NaN                    NaN
# CSM79HH8                    NaN                    NaN
# CSM79HJM                    NaN                    NaN
# CSM79HNU                    NaN                    NaN
# ESM5MEDN                    NaN                    NaN
# ESM718V8                    NaN                    NaN
# HSM5FZBZ                    NaN                    NaN
# HSM5MD4Y                    NaN                    NaN
# HSM5MD7O                    NaN                    NaN
# HSM5MD4O                    NaN                    NaN
# HSM5MD6A                    NaN                    NaN
# HSM5MD62                    NaN                    NaN
# HSM67VIF                    NaN                    NaN
# HSM7CZ3G                    NaN                    NaN
# HSM7J4Q7                    NaN                    NaN
# MSM5LLDI                    NaN                    NaN
# MSM5LLGL                    NaN                    NaN
# MSM6J2LT                    NaN                    NaN
# MSM6J2J5                    NaN                    NaN
# MSM6J2KE                    NaN                    NaN
# MSM6J2IG                    NaN                    NaN
# MSM5LLF4                    NaN                    NaN
# MSM79HDQ                    NaN                    NaN
# MSM9VZPL                    NaN                    NaN
# PSM6XBQY                    NaN                    NaN
# PSM6XBRK                    NaN                    NaN
# PSM6XBSI                    NaN                    NaN
# PSM7J19F                    NaN                    NaN
# PSM7J12J                    NaN                    NaN
#
# Abundance    s__Bacteroidales_bacterium_KA00251  s__Parvimonas_sp_KA00067
# External ID
# CSM67UA2                                    NaN                       NaN
# CSM5MCVN                                    NaN                       NaN
# CSM5MCZ3                                    NaN                       NaN
# CSM5MCWE                                    NaN                       NaN
# CSM67UCK                                    NaN                       NaN
# CSM5MCZF                                    NaN                       NaN
# CSM67UB1                                    NaN                       NaN
# CSM67UBB                                    NaN                       NaN
# CSM79HH8                                    NaN                       NaN
# CSM79HJM                                    NaN                       NaN
# CSM79HNU                                    NaN                       NaN
# ESM5MEDN                                    NaN                       NaN
# ESM718V8                                    NaN                       NaN
# HSM5FZBZ                                    NaN                       NaN
# HSM5MD4Y                                    NaN                       NaN
# HSM5MD7O                                    NaN                       NaN
# HSM5MD4O                                    NaN                       NaN
# HSM5MD6A                                    NaN                       NaN
# HSM5MD62                                    NaN                       NaN
# HSM67VIF                                    NaN                       NaN
# HSM7CZ3G                                    NaN                       NaN
# HSM7J4Q7                                    NaN                       NaN
# MSM5LLDI                                    NaN                       NaN
# MSM5LLGL                                    NaN                       NaN
# MSM6J2LT                                    NaN                       NaN
# MSM6J2J5                                    NaN                       NaN
# MSM6J2KE                                    NaN                       NaN
# MSM6J2IG                                    NaN                       NaN
# MSM5LLF4                                    NaN                       NaN
# MSM79HDQ                                    NaN                       NaN
# MSM9VZPL                                    NaN                       NaN
# PSM6XBQY                                    NaN                       NaN
# PSM6XBRK                                    NaN                       NaN
# PSM6XBSI                                    NaN                       NaN
# PSM7J19F                                    NaN                       NaN
# PSM7J12J                                    NaN                       NaN
#
# [36 rows x 1218 columns]

# %% [markdown]
# Deletes all values smaller than the threshold value

# %%
Threshold = 0.1
M_CD = M_CD_B[M_CD_B >= Threshold]
M_UC = M_UC_B[M_UC_B >= Threshold]
M_Control = M_Control_B[M_Control_B >= Threshold]
print(f'Dim_CD:{M_CD.shape}\tDim_UC:{M_UC.shape}\tDim_Control:{M_Control.shape}')
# Out:
# Dim_CD:(36, 1218)	Dim_UC:(24, 1218)	Dim_Control:(23, 1218)

# %% [markdown]
# Replace NaN Values with Zero

# %%
###########
M_CD = M_CD.fillna(0)
M_CD[M_CD >= Threshold] = 1
M_CD[M_CD < Threshold] = 0
###########
M_UC = M_UC.fillna(0)
M_UC[M_UC >= Threshold] = 1
M_UC[M_UC < Threshold] = 0
###########
M_Control = M_Control.fillna(0)
M_Control[M_Control >= Threshold] = 1
M_Control[M_Control < Threshold] = 0

# %%
M_CD = M_CD.loc[:,(M_CD.sum() > M_CD.shape[0] * 0.1) & (M_CD.sum() < M_CD.shape[0]*0.9)]
M_UC = M_UC.loc[:, (M_UC.sum() > M_UC.shape[0] * 0.1)  & (M_UC.sum() < M_UC.shape[0]*0.9)]
M_Control = M_Control.loc[:, (M_Control.sum() > M_Control.shape[0] * 0.1)  & (M_Control.sum() < M_Control.shape[0]*0.9)]
print(f'Dim_CD:{M_CD.shape}\tDim_UC:{M_UC.shape}\tDim_Control:{M_Control.shape}')
# Out:
# Dim_CD:(36, 103)	Dim_UC:(24, 108)	Dim_Control:(23, 120)

# %%
random.seed(8)
M_CD_R = M_CD.apply(lambda x: np.random.permutation(x),)
M_UC_R = M_UC.apply(lambda x: np.random.permutation(x))
M_Control_R  = M_Control.apply(lambda x: np.random.permutation(x))

# %%
# This function creates npermute random permutations of x and y and counts how many times (n)
# the random permutations give a jaccard index that is better than the real one. n/npermute is
# the pvalue. if n==0 and npermute<10000 the function will calculate the pvalue again with

def jaccard_pval_formula(x, y):
    k = np.sum(x & y)
    nx, ny = np.sum(x), np.sum(y)
    if nx < ny:
        nx, ny = ny, nx

    rv = hypergeom(x.size, nx, ny)
    return np.sum(rv.pmf(np.arange(k, ny+1)))

def create_jaccard_pvals_table(df):
    # get the column names of the DataFrame
    col_names = df.columns
    result = pd.DataFrame({"Species1": ["None"], "Species2": ["None"], "Jaccard": [-1.0], "Pval": [-1.0]})
    for i in range(len(df.columns)):
        col1 = col_names[i]
        a = np.array(df[col1])
        for j in range(i+1, len(df.columns)):
            col2 = col_names[j]
            b = np.array(df[col2])
            jaccard = float(np.sum(a & b)/np.sum(a | b))
            pval = jaccard_pval_formula(a, b)

            newRow = pd.DataFrame({"Species1": [col1], "Species2": [col2], "Jaccard": [jaccard], "Pval": [pval]})
            result = pd.concat([result, newRow])
    result = result.iloc[1:result.shape[0], :].sort_values(by="Pval")
    result["FDR"] = mc.fdrcorrection(result["Pval"])[1]
    result.index = range(0, result.shape[0])
    return result

# This is a toy example - species are A, B, C, ...
# df2 = pd.DataFrame({"A": [1, 0, 1, 0, 1, 1, 0], "B": [1, 1, 0, 0, 0, 1, 0], "C": [1, 1, 1, 0, 1, 1, 1], "D": [1, 0, 0, 0, 0, 1, 0], "E": [1, 1, 0, 0, 0, 1, 0]})

# %%
M = M_CD.astype(int)
df = create_jaccard_pvals_table(M)
sns.kdeplot(df.Pval)
plt.show()

# %%
M = df.loc[df.Pval <= 0.0033]
M
# Out:
#                                 Species1  \
# 0                s__Oscillibacter_sp_ER4
# 1        s__Faecalibacterium_prausnitzii
# 2                s__Oscillibacter_sp_ER4
# 3                       s__Blautia_obeum
# 4              s__Parabacteroides_merdae
# 5                s__Phocaeicola_vulgatus
# 6           s__Faecalibacterium_SGB15346
# 7            s__Odoribacter_splanchnicus
# 8            s__Clostridiaceae_bacterium
# 9               s__Bacteroides_uniformis
# 10               s__Clostridia_bacterium
# 11       s__Faecalibacterium_prausnitzii
# 12       s__Faecalibacterium_prausnitzii
# 13          s__Faecalibacterium_SGB15346
# 14           s__Odoribacter_splanchnicus
# 15                s__Veillonella_parvula
# 16           s__Streptococcus_salivarius
# 17           s__Clostridium_sp_AF34_10BH
# 18                s__Anaerostipes_hadrus
# 19                s__Anaerostipes_hadrus
# 20                   s__GGB9615_SGB15053
# 21       s__Barnesiella_intestinihominis
# 22             s__Bifidobacterium_longum
# 23              s__Bacteroides_uniformis
# 24               s__Alistipes_finegoldii
# 25           s__Odoribacter_splanchnicus
# 26       s__Bacteroides_cellulosilyticus
# 27       s__Faecalibacterium_prausnitzii
# 28          s__Faecalibacterium_SGB15346
# 29               s__Alistipes_putredinis
# 30            s__Dysosmobacter_welbionis
# 31           s__Clostridium_sp_AF34_10BH
# 32                  s__Roseburia_hominis
# 33          s__Ruminococcaceae_bacterium
# 34               s__Clostridium_innocuum
# 35           s__Prevotella_copri_clade_A
# 36                 s__Clostridium_fessum
# 37              s__Clostridium_sp_AF36_4
# 38  s__Candidatus_Cibiobacter_qucibialis
# 39                      s__Blautia_obeum
# 40               s__Phocaeicola_vulgatus
# 41           s__Clostridiaceae_bacterium
# 42           s__Clostridium_sp_AM22_11AC
# 43  s__Candidatus_Cibiobacter_qucibialis
# 44               s__Alistipes_putredinis
# 45       s__Faecalibacterium_prausnitzii
# 46           s__Odoribacter_splanchnicus
#
#                                 Species2   Jaccard      Pval       FDR
# 0                    s__GGB9615_SGB15053  0.666667  0.000012  0.062060
# 1                  s__Bacteroides_caccae  0.777778  0.000053  0.119943
# 2                 s__Lachnospira_eligens  0.588235  0.000077  0.119943
# 3                s__Oscillibacter_sp_ER4  0.600000  0.000108  0.119943
# 4                  s__Bacteroides_caccae  0.681818  0.000114  0.119943
# 5               s__Bacteroides_uniformis  0.821429  0.000200  0.160140
# 6                 s__Lachnospira_eligens  0.529412  0.000258  0.160140
# 7                    s__GGB9615_SGB15053  0.636364  0.000323  0.160140
# 8                s__Blautia_massiliensis  0.555556  0.000334  0.160140
# 9            s__Odoribacter_splanchnicus  0.740741  0.000425  0.160140
# 10           s__Odoribacter_splanchnicus  0.740741  0.000425  0.160140
# 11              s__Bacteroides_uniformis  0.827586  0.000427  0.160140
# 12                 s__Bacteroides_ovatus  0.827586  0.000427  0.160140
# 13               s__Oscillibacter_sp_ER4  0.583333  0.000427  0.160140
# 14                   s__GGB9632_SGB15089  0.523810  0.000587  0.183601
# 15                s__Veillonella_atypica  0.571429  0.000594  0.183601
# 16        s__Streptococcus_parasanguinis  0.571429  0.000594  0.183601
# 17       s__Barnesiella_intestinihominis  0.538462  0.000645  0.188089
# 18                  s__Dorea_longicatena  0.588235  0.000704  0.194738
# 19                      s__Blautia_obeum  0.461538  0.000881  0.231394
# 20                s__Lachnospira_eligens  0.600000  0.001152  0.267726
# 21                    s__GGB1420_SGB1957  0.500000  0.001188  0.267726
# 22  s__Bifidobacterium_pseudocatenulatum  0.500000  0.001188  0.267726
# 23               s__Clostridia_bacterium  0.793103  0.001286  0.267726
# 24              s__Alistipes_onderdonkii  0.526316  0.001364  0.267726
# 25               s__Oscillibacter_sp_ER4  0.476190  0.001388  0.267726
# 26              s__Alistipes_onderdonkii  0.444444  0.001446  0.267726
# 27               s__Alistipes_putredinis  0.714286  0.001489  0.267726
# 28                   s__GGB9615_SGB15053  0.500000  0.001489  0.267726
# 29           s__Odoribacter_splanchnicus  0.680000  0.001580  0.267726
# 30             s__Flavonifractor_plautii  0.680000  0.001580  0.267726
# 31               s__Alistipes_finegoldii  0.533333  0.001771  0.290767
# 32                s__Lachnospira_eligens  0.500000  0.001894  0.301433
# 33            s__Coprobacter_fastidiosus  0.444444  0.002139  0.319553
# 34               s__Hungatella_hathewayi  0.600000  0.002190  0.319553
# 35                   s__GGB9635_SGB15106  0.600000  0.002190  0.319553
# 36              s__Alistipes_onderdonkii  0.550000  0.002255  0.320208
# 37                s__Lachnospira_eligens  0.411765  0.002330  0.322057
# 38          s__Faecalibacterium_SGB15346  0.500000  0.002450  0.330055
# 39                   s__GGB9615_SGB15053  0.400000  0.002570  0.336122
# 40       s__Bacteroides_thetaiotaomicron  0.615385  0.002740  0.336122
# 41          s__Faecalibacterium_SGB15346  0.500000  0.002747  0.336122
# 42   s__Parasutterella_excrementihominis  0.461538  0.002751  0.336122
# 43                s__Lachnospira_eligens  0.526316  0.002850  0.340219
# 44              s__Alistipes_onderdonkii  0.625000  0.002966  0.346244
# 45                   s__GGB9615_SGB15053  0.555556  0.003122  0.348951
# 46          s__Faecalibacterium_SGB15346  0.428571  0.003122  0.348951

# %%
M.shape
# Out:
# (0, 5)

# %%
print(sum(M_CD.s__Flavonifractor_plautii > 0.1))
print(sum((M_CD.s__Flavonifractor_plautii > 0.1)*(M_CD.s__Dysosmobacter_welbionis > 0.1)))
# sum(M_CD.s__Dysosmobacter_welbionis > 0.1)
# Out:
# 21
# 17

# %%
Cluster_CD = Metaphlan4.loc[:,['s__Dysosmobacter_welbionis','s__Flavonifractor_plautii']]

# %%
Name_Hierarchical_CD = pd.read_csv('~/Desktop/Metaphlan4_set_species_CD.csv')
Name_Hierarchical_CD.set_index('Unnamed: 0',inplace=True)
sum_samples = pd.DataFrame(M_CD.sum())
HCD = Cluster_CD.T.join(sum_samples)
Hierarchical_CD = HCD.join(Name_Hierarchical_CD)
Hierarchical_CD.rename(columns={Hierarchical_CD.columns[-1]:'Hierarchical', Hierarchical_CD.columns[-2]:'Sum_Samples'}, inplace=True)
Hierarchical_CD
# Out:
#                             CSM67UA2  CSM5MCVN  CSM67UBZ  CSM5MCXL  CSM5MCY8  \
# Abundance
# s__Dysosmobacter_welbionis   1.01564   0.00000   0.40071   1.67904   0.73681
# s__Flavonifractor_plautii    1.27997   0.71989   0.15991   1.35344   0.21178
#
#                             CSM5MCX3  CSM5MCZ3  CSM5MCWE  CSM67UCK  CSM67UEW  \
# Abundance
# s__Dysosmobacter_welbionis   0.07861   0.62252   4.82675   0.09141   0.02074
# s__Flavonifractor_plautii    0.02331   0.87682   0.91283   0.00000   0.00000
#
#                             ...  PSM6XBT3  PSM7J14X  PSM7J19F  PSM7J19N  \
# Abundance                   ...
# s__Dysosmobacter_welbionis  ...   0.24466   0.42869   0.47976   0.14108
# s__Flavonifractor_plautii   ...   0.11067   0.03173   0.51072   0.00421
#
#                             PSM6XBW3  PSM7J12J  PSM7J1BX  PSMA264O  \
# Abundance
# s__Dysosmobacter_welbionis   0.00000   0.00000   0.34516   0.00486
# s__Flavonifractor_plautii    3.28992   0.96176   0.02811   0.44295
#
#                             Sum_Samples  \
# Abundance
# s__Dysosmobacter_welbionis         21.0
# s__Flavonifractor_plautii          21.0
#
#                                                                  Hierarchical
# Abundance
# s__Dysosmobacter_welbionis  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...
# s__Flavonifractor_plautii   k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...
#
# [2 rows x 85 columns]
